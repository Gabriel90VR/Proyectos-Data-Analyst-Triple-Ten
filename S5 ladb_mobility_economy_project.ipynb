# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>¡Hola! Gabriel👋</b>
#
# Mi nombre es Santiago. Un gusto acompañarte en este proyecto del Sprint 5.
#
# Antes de empezar, te comparto cómo funciona la revisión:
# <ul>
# <li>Cuando encuentre un error, lo señalaré para que lo detectes y corrijas por tu cuenta.</li>
# <li>Si en algún punto no logras resolver algo, en la siguiente iteración te daré una pista más concreta.</li>
# <li>Por favor no muevas ni elimines mis comentarios. Puedes responder debajo usando un bloque de texto.</li>
# </ul>
#
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor.</b>
# Éxito. ✅
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor.</b>
# Observación. No bloquea la aprobación.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor.</b>
# Necesita ajustes antes de aprobar.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Review General. (Iteración 1)</b>
#
# Antes de entrar en el detalle, quiero resaltar lo que está muy bien: el renombrado de columnas quedó completo y correcto en ambas tablas, la limpieza numérica produce los valores correctos (18117.0 para Buenos Aires 2024 — sin la corrupción ×10 que he visto en otros proyectos), los filtros de 2024 están bien aplicados, el groupby está sobre <code>traffic_2024</code>, el merge produce las 15 ciudades correctas, el boxplot tiene <code>showmeans=True</code>, y el CSV se exportó. Buen trabajo técnico.
#
# Lo que necesita corrección tiene que ver principalmente con las <b>secciones de texto</b>:
#
# <ol>
# <li><b>🔴 Cuatro celdas de texto sin completar:</b> observaciones del EDA (celdas 10 y 12), la ciudad con mayor tráfico (celda 28), y los comentarios sobre los gráficos (celda 38).</li>
# <li><b>🔴 El resumen ejecutivo (celda 43) está en una celda de código</b>, usa sintaxis de comentario Python (<code>#</code>) en lugar de Markdown, nunca fue ejecutado, y tiene un error factual que debes revisar.</li>
# </ol>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Review General. (Iteración 2)</b>
#
# ¡Hola, Gabriel! Esta segunda iteración tiene avances muy reales. Antes de entrar al detalle, te confirmo lo que quedó bien resuelto:
#
# <ul>
# <li>✅ <b>EDA de eco (celda 15) completada:</b> identificas que las columnas numéricas están como texto y necesitan conversión a float.</li>
# <li>✅ <b>Reflexión Paso 4 (celda 37) completada:</b> Ciudad de México con ~2833 min, comparación con Tokyo y Nueva York. Excelente nivel de detalle.</li>
# <li>✅ <b>Reflexión de los gráficos (celdas 54 y 55):</b> hay análisis propio con la identificación de Montevideo como caso atípico.</li>
# <li>✅ <b>Resumen ejecutivo ahora en celda Markdown</b> (no código): estructura muy completa, con contexto, hallazgos, recomendaciones concretas y conclusiones.</li>
# </ul>
#
# Tengo <b>tres puntos que siguen pendientes</b>:
# <ol>
# <li>🔴 <b>EDA de traffic (celda 12):</b> sigue con el texto de plantilla sin completar.</li>
# <li>🔴 <b>Error factual en el ranking del resumen ejecutivo:</b> el top 5 coloca a Bogotá como #1, pero Ciudad de México es la ciudad más congestionada (~2833 min). Este punto fue señalado en la iteración anterior.</li>
# <li>🔴 <b>CSV sin exportar</b>: la celda 57 tiene <code>execution_count = None</code> — nunca fue ejecutada.</li>
# </ol>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Review General. (Iteración 3)</b>
#
# ¡Hola, Gabriel! En esta iteración cerraste los tres bloqueantes que quedaban de la iteración 2. Los revisé uno por uno:
#
# <ol>
# <li>✅ <b>EDA de traffic completada:</b> la celda 11 tiene la observación correcta: "Las columnas UpdateTimeUTC y UpdateTimeUTCWeekAgo están en formato texto, se convertirá a formato fecha para extraer el año". ✅</li>
# <li>✅ <b>Ranking del resumen ejecutivo corregido:</b> el top 5 ahora dice correctamente <b>1. Ciudad de México, 2. Sao Paulo, 3. Bogotá, 4. Lima, 5. Buenos Aires</b>. ✅</li>
# <li>✅ <b>CSV exportado</b>: la celda del export tiene <code>exec=18</code> — fue ejecutada correctamente dentro de una ejecución lineal 1→18. ✅</li>
# </ol>
#
# Solo te dejo una observación menor (🟡) de limpieza.
#
# </div>

# %% [markdown]
# ## Introducción
#
# Como analista de datos, tu objetivo es **evaluar cómo la movilidad urbana se relaciona con la productividad económica en las principales ciudades latinoamericanas**.
# Para ello trabajarás con datos reales de TomTom Traffic Index y OECD Cities, que deberás limpiar, combinar y analizar para identificar en qué ciudades conviene invertir en infraestructura de transporte.

# %% [markdown]
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de ambos datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯Objetivo:**
# Importar las librerías necesarias, cargar los archivos CSV en DataFrames y realizar una revisión preliminar para entender su contenido.
#
# **Instrucciones:**
# - Importa las librerías `pandas`, `numpy`, `seaborn` y `matplotlib.pyplot`.
# - Carga los archivos usando `pd.read_csv()`:
#   - `'/datasets/tomtom_traffic.csv'`
#   - `/datasets/oecd_city_economy.csv` `.
# - Guarda los DataFrames en las variables `traffic` y `eco`.
# - Muestra las primeras 5 filas de cada DataFrame.

# %%
# importar librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# cargar archivos
traffic = pd.read_csv('/datasets/tomtom_traffic.csv')
eco = pd.read_csv ('/datasets/oecd_city_economy.csv') #completa el código

# %%
traffic.head(5) # mostrar las primeras 5 filas de traffic
# Out:
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
# 3     ARE  abu-dhabi  2025-01-13 01:46:30.001        8.2               2.0
# 4     ARE  abu-dhabi  2025-01-13 00:01:30.000        1.1               1.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
# 3              4.1        2.0                  2.0  2025-01-06 01:46:30.000
# 4              0.2        1.0                  1.0  2025-01-06 00:01:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232
# 3                    7.723808                        7.899046  -0.175238
# 4                    8.336363                        8.604379  -0.268016

# %%
eco.head (5) # mostrar las primeras 5 filas de eco
# Out:
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
# 3  2023        brasilia     Brazil       15.999,00           8.3%
# 4  2023        salvador     Brazil        8.761,00          13.1%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60
# 3         13,50           4,70
# 4         16,00           3,90

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Explorar, limpiar y preparar los datos
#
# Antes de combinar los datasets, inspecciona su estructura, tipos de datos, columnas y valores faltantes.
# Anota las columnas que necesiten limpieza y luego estandariza los nombres de columnas.
#
# ### 2.1 Explorar la estructura y tipos de datos
#
# **🎯Objetivo:**
# Identificar columnas con tipos incorrectos, distribución y nulos, anotar las columnas que requieren conversión.
#
# **Instrucciones:**
#
# - Usa `.info()` para conocer la estructura de ambos DataFrames.
# - Muestra los primeros 3 renglones de cada DF.
# - Identifica si los detalles de cada DF estan bien o si requieren correcciones y escribe tus conclusiones en el bloque Markdown.
#   - ¿Hay columnas que requieren conversión?¿ Cuáles son? ¿Que tipo de dato ienen y cuál deberían de tener?
#   - ¿Hay datos ausentes en alguna columna?

# %% [markdown]
# # Examinar la estructura de traffic
# traffic.info()
# traffic.head(3)
# ## Las columnas UpdateTimeUTC y UpdateTimeUTCWeekAgo estan en formato texto, se convertira a formato fecha para extraer el año del que necesitamos la consulta.

# %% [markdown]
# En la estructura del DF traffic, se observa que:
# - Las columnas `UpdateTimeUTC` y `UpdateTimeUTC` son de tipo ...
# - ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor. (Iteración 3)</b>
# La observación del EDA de traffic está escrita en la celda 11 (el encabezado <code>## Las columnas UpdateTimeUTC...</code>) ✅. La celda 12 es el placeholder original que quedó sin eliminar. No bloquea la aprobación, pero puedes borrar esa celda 12 para que el notebook quede más limpio.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor. (Iteración 1)</b>
# Esta celda de observación quedó con el texto de plantilla sin completar. El output del <code>.info()</code> de arriba tiene toda la información que necesitas — solo escribe con tus propias palabras qué columnas tienen tipos incorrectos y qué conversiones habría que hacerles.
# </div>

# %%
# Examinar la estructura de eco
eco.info()
eco.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             30 non-null     int64
#  1   City             30 non-null     object
#  2   Country          30 non-null     object
#  3   City GDP/capita  30 non-null     object
#  4   Unemployment %   30 non-null     object
#  5   PM2.5 (μg/m³)    30 non-null     object
#  6   Population (M)   30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60

# %% [markdown]
# # En la estructura del DF eco, se observa que:
# ## Las columnas `City GDP/capita`, `Unemployment %`, PM2.5 Y Polulation (M), son de formato texto, necesitamos formato numerico para hacer los calculos necesarios.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 2)</b>
# EDA de eco completada: identificas que <code>City GDP/capita</code>, <code>Unemployment %</code>, <code>PM2.5</code> y <code>Population (M)</code> están como texto y necesitan conversión a numérico. ✅
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor. (Iteración 1)</b>
# Esta celda de observación quedó con el texto de plantilla sin completar. El output del <code>.info()</code> de arriba tiene toda la información que necesitas — solo escribe con tus propias palabras qué columnas tienen tipos incorrectos y qué conversiones habría que hacerles.
# </div>

# %% [markdown]
# ### 2.2 Renombrar columnas
#
# **🎯Objetivo:**
# Estandarizar los nombres de columnas para evitar errores y facilitar la unión de los datasets.
#
# **Instrucciones:**
#
# - Cambia los nombres de las columnas para que tengan el formato `snake_case`.
#     - `Country` → `country`
#     - `UpdateTimeUTC` → `update_time_utc`
# - Verifica que los cambios se hayan aplicado correctamente usando `.columns`.

# %%
# Estandarizar los nombres de las columnas de traffic
#tu código aquí
traffic = traffic.rename(columns={"Country": "country", "City": "city", "UpdateTimeUTC": "update_time_utc", "JamsDelay": "jams_delay", 
                                  "TrafficIndexLive": "traffic_index_live", "JamsLengthInKms": "jams_length_kms",
                                  "JamsCount": "jams_count", "TrafficIndexWeekAgo": "traffic_index_week_ago", "MinsDelay": "mins_delay","UpdateTimeUTCWeekAgo" : "update_time_utc_week_ago",
                                 "TravelTimeLivePer10KmsMins": "travel_time_live_per_10kms_mins", "TravelTimeHistoricPer10KmsMins": "travel_time_hist_per_10kms_mins"})

# verificar cambios
traffic.columns
# Out:
# Index(['country', 'city', 'update_time_utc', 'jams_delay',
#        'traffic_index_live', 'jams_length_kms', 'jams_count',
#        'traffic_index_week_ago', 'update_time_utc_week_ago',
#        'travel_time_live_per_10kms_mins', 'travel_time_hist_per_10kms_mins',
#        'mins_delay'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b>
# Renombrado de traffic completo y correcto: las 12 columnas en <code>snake_case</code> limpio. Coincide con el solucionario. ✅
# </div>

# %%
# Estandarizar los nombres de las columnas de eco
#tu código aquí
eco = eco.rename(columns={"Year": "year", "City": "city", "Country": "country", "City GDP/capita" : "city_gdp_capita", "Unemployment %" : "unemployment_pct", "PM2.5 (μg/m³)" : "pm25", "Population (M)" : "population_m" })
# verificar cambios
eco.columns
# Out:
# Index(['year', 'city', 'country', 'city_gdp_capita', 'unemployment_pct',
#        'pm25', 'population_m'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b>
# Renombrado de eco completo y correcto: las 7 columnas en <code>snake_case</code>, incluyendo el buen uso de <code>city_gdp_capita</code> (coincide con el solucionario) y <code>unemployment_pct</code>. ✅
# </div>

# %% [markdown]
# ### 2.3 Corregir formatos numéricos y de fecha
#
# **🎯Objetivo:**
# Asegurar que las columnas de fechas y valores numéricos estén en formatos correctos para permitir análisis, cálculos y comparaciones precisas.
#
# **Instrucciones:**
#
# - Convierte las columnas de fecha de `traffic` a formato `datetime`. Haz el cambio a prueba de errores.
# - En el dataset `eco`, limpia los valores numéricos:
#     - En `city_gdp_capita`: elimina separadores de miles (`.`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `unemployment_pct`: elimina el símbolo de porcentaje (`%`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `population_m`: reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
# - Finalmente, crea una nueva columna llamada `population` multiplicando `population_m` por 1,000,000 para obtener la población total.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# para eliminar símbolos, puedes reemplazarlos por un texto vacío.

# %%
# Convertir las columnas de traffic a tipo fecha con pd.to_datetime()
traffic['update_time_utc'] = pd.to_datetime(traffic['update_time_utc'], errors = 'coerce') #tu código aquí
traffic['update_time_utc_week_ago'] = pd.to_datetime (traffic['update_time_utc_week_ago'], errors = 'coerce') #tu código aquí

# verificar el cambio
traffic.info()
traffic.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   country                          1004464 non-null  object
#  1   city                             1004464 non-null  object
#  2   update_time_utc                  1004464 non-null  datetime64[ns]
#  3   jams_delay                       1004464 non-null  float64
#  4   traffic_index_live               1004464 non-null  float64
#  5   jams_length_kms                  1004464 non-null  float64
#  6   jams_count                       1004464 non-null  float64
#  7   traffic_index_week_ago           1004464 non-null  float64
#  8   update_time_utc_week_ago         1004464 non-null  datetime64[ns]
#  9   travel_time_live_per_10kms_mins  1004464 non-null  float64
#  10  travel_time_hist_per_10kms_mins  1004464 non-null  float64
#  11  mins_delay                       1004464 non-null  float64
# dtypes: datetime64[ns](2), float64(8), object(2)
# memory usage: 92.0+ MB
#   country       city         update_time_utc  jams_delay  traffic_index_live  \
# 0     ARE  abu-dhabi 2025-01-13 04:01:30.001       650.7                36.0
# 1     ARE  abu-dhabi 2025-01-13 03:46:00.000       540.4                30.0
# 2     ARE  abu-dhabi 2025-01-13 02:46:30.000        71.8                 7.0
#
#    jams_length_kms  jams_count  traffic_index_week_ago  \
# 0            109.1       162.0                    30.0
# 1            101.4       136.0                    27.0
# 2             18.9        23.0                     6.0
#
#   update_time_utc_week_ago  travel_time_live_per_10kms_mins  \
# 0  2025-01-06 04:01:30.000                        11.614767
# 1  2025-01-06 03:46:30.001                        11.003180
# 2  2025-01-06 02:46:30.000                         8.196278
#
#    travel_time_hist_per_10kms_mins  mins_delay
# 0                        10.265330    1.349437
# 1                        10.031544    0.971635
# 2                         8.196510   -0.000232

# %%
# Limpia separadores y convierte columnas numéricas en eco
eco['city_gdp_capita'] = eco['city_gdp_capita'].astype(str).str.replace('.', '').str.replace(',', '.').astype(float)
eco['unemployment_pct'] = eco['unemployment_pct'].astype(str).str.replace('%', '').str.replace(',', '.').astype(float)
eco['population_m'] = eco['population_m'].astype(str).str.replace(',', '.').astype(float)


# Calcula la población total en unidades absolutas (Multiplica * 1000000)
eco['population'] = eco['population_m'] * 1000000
 

# verificar el cambio
eco.info()
eco.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              30 non-null     int64
#  1   city              30 non-null     object
#  2   country           30 non-null     object
#  3   city_gdp_capita   30 non-null     float64
#  4   unemployment_pct  30 non-null     float64
#  5   pm25              30 non-null     object
#  6   population_m      30 non-null     float64
#  7   population        30 non-null     float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 2.0+ KB
#    year            city    country  city_gdp_capita  unemployment_pct   pm25  \
# 0  2023    buenos-aires  Argentina          15782.0               6.2   15,2
# 1  2023       sao-paulo     Brazil          14475.0               9.1  29,50
# 2  2023  rio-de-janeiro     Brazil          13142.0               9.8  19,10
#
#    population_m  population
# 0          15.3  15300000.0
# 1          22.5  22500000.0
# 2          13.6  13600000.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b>
# Limpieza numérica impecable:
# <ul>
# <li><code>city_gdp_capita</code>: Buenos Aires 2024 = <b>18117.0</b> — correcto, sin corrupción. ✅</li>
# <li><code>unemployment_pct</code>: Buenos Aires 2024 = <b>7.2</b>. ✅</li>
# <li><code>population</code>: calculada correctamente en unidades absolutas. ✅</li>
# </ul>
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Extraer año y filtrar
#
# Extraer el año permite filtrar la información y trabajar solo con el período más reciente y relevante.
#
# ### 3.1 Extraer columna año y filtrar 2024
#
# **🎯Objetivo**
# Identificar el año de cada registro y mantener solo los registros del 2024.
#
# **Intrucciones**
#
# - Como el DataFrame `traffic` no tiene una columna de año, utiliza el atributo `.dt.year` sobre su columna de fecha para crear una nueva columna llamada `year`.
# - Filtra las filas donde el año sea **2024**.
# - Utiliza `.copy()` para crear dos nuevos DataFrames (`traffic_2024` y `eco_2024`) para evitar modificar el dataset original.

# %%
# Extraer el año de las fechas en update_time_utc
traffic['year'] = traffic['update_time_utc'].dt.year
eco ['year'].unique()

# Verificar cambio
traffic.head(3)
eco.head(3)
# Out:
#    year            city    country  city_gdp_capita  unemployment_pct   pm25  \
# 0  2023    buenos-aires  Argentina          15782.0               6.2   15,2
# 1  2023       sao-paulo     Brazil          14475.0               9.1  29,50
# 2  2023  rio-de-janeiro     Brazil          13142.0               9.8  19,10
#
#    population_m  population
# 0          15.3  15300000.0
# 1          22.5  22500000.0
# 2          13.6  13600000.0

# %%
# Filtra los registros del año 2024
traffic_2024 = traffic[traffic['year'] == 2024].copy()
eco_2024 = eco[eco['year'] == 2024].copy()

# Revisar dataframes nuevos
display(traffic_2024.head())
display(eco_2024.head())
# Out:
#     country       city         update_time_utc  jams_delay  \
# 302     ARE  abu-dhabi 2024-12-31 23:01:30.000        12.9
# 303     ARE  abu-dhabi 2024-12-31 22:01:30.000       136.0
# 304     ARE  abu-dhabi 2024-12-31 21:16:30.000       455.2
# 305     ARE  abu-dhabi 2024-12-31 20:01:00.001       399.4
# 306     ARE  abu-dhabi 2024-12-31 19:46:00.000       366.4
#
#      traffic_index_live  jams_length_kms  jams_count  traffic_index_week_ago  \
# 302                 5.0              2.5         5.0                     2.0
# 303                21.0             20.6        32.0                     3.0
# 304                31.0             40.4        72.0                     4.0
# 305                27.0             38.0        75.0                     6.0
# 306                28.0             39.8        82.0                     9.0
#
#     update_time_utc_week_ago  travel_time_live_per_10kms_mins  \
# 302  2024-12-24 23:01:30.001                         8.560399
# 303  2024-12-24 22:01:30.000                        10.355732
# 304  2024-12-24 21:01:30.000                        11.456878
# 305  2024-12-24 20:01:30.001                        11.670062
# 306  2024-12-24 19:01:00.000                        11.686322
#
#      travel_time_hist_per_10kms_mins  mins_delay  year
# 302                         8.519634    0.040765  2024
# 303                         9.049445    1.306286  2024
# 304                         9.305174    2.151704  2024
# 305                         9.952811    1.717252  2024
# 306                        10.008469    1.677853  2024
#     year            city    country  city_gdp_capita  unemployment_pct   pm25  \
# 15  2024    buenos-aires  Argentina          18117.0               7.2  14,50
# 16  2024       sao-paulo     Brazil          14703.0               8.5  28,00
# 17  2024  rio-de-janeiro     Brazil          13349.0               9.2  18,40
# 18  2024        brasilia     Brazil          16251.0               7.8  12,80
# 19  2024        salvador     Brazil           8899.0              12.4  15,20
#
#     population_m  population
# 15          15.4  15400000.0
# 16          22.6  22600000.0
# 17          13.7  13700000.0
# 18           4.8   4800000.0
# 19           3.9   3900000.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b>
# Filtros correctos: <code>traffic_2024</code> y <code>eco_2024</code> con <code>year == 2024</code> y <code>.copy()</code>. ✅
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Analizar y resumir datos de movilidad
#
# Como el dataset de tráfico contiene **múltiples registros por ciudad**. En esta parte, calcularás los promedios anuales por ciudad para simplificar el análisis y obtener una visión más clara de las tendencias generales.
#
# ### 4.1 Calcular promedios de tráfico por ciudad
#
# **🎯Objetivo:**
# Obtener una vista consolidada del tráfico promedio por ciudad y año, para analizar patrones generales sin depender de datos diarios.
#
# **Instrucciones**
#
# - Agrupa los datos por `city`, `country` y `year`.
# - Calcula el promedio **solo de las métricas de tráfico más relevantes**: como `jams_delay`, `traffic_index_live`, `jams_length_kms`, `jams_count`, `mins_delay`, y tiempos de viaje (`travel_time_live_per_10kms_mins` y `travel_time_hist_per_10kms_mins`).
# - Guarda el resultado como `traffic_city_year_2024`, mantén las columnas como variables (no índices).

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa ".agg()" para aplicar funciones de promedio. Al final, reinicia el índice para mantener las columnas de la agrupación como variables (no índices).

# %%
# Calcular los  promedios de trafico por ciudad, país y año
traffic_city_year_2024 = traffic_2024.groupby(['city', 'country', 'year'])[['jams_delay', 'traffic_index_live', 'jams_length_kms', 'jams_count', 'mins_delay',
      'travel_time_live_per_10kms_mins', 'travel_time_hist_per_10kms_mins']].agg('mean').reset_index()

# Mostrar resultado
traffic_city_year_2024.head()
# Out:
#         city country  year  jams_delay  traffic_index_live  jams_length_kms  \
# 0   a-coruna     ESP  2024   17.935187           15.259774         2.198002
# 1     aachen     DEU  2024   26.732141           20.960314         3.892586
# 2     aarhus     DNK  2024   21.200616           16.575891         2.736736
# 3  abu-dhabi     ARE  2024  171.157315           13.902028        24.507380
# 4      adana     TUR  2024   83.864761           22.541040        11.827331
#
#    jams_count  mins_delay  travel_time_live_per_10kms_mins  \
# 0    4.934405    0.774172                        16.267977
# 1    6.601832    0.792968                        13.397861
# 2    6.109987    0.495276                        15.219292
# 3   47.268019    0.139764                         9.829092
# 4   23.754620    1.129749                        15.879694
#
#    travel_time_hist_per_10kms_mins
# 0                        15.493804
# 1                        12.604894
# 2                        14.724016
# 3                         9.689328
# 4                        14.749945

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b>
# Groupby correcto: sobre <code>traffic_2024</code>, con <code>.agg('mean')</code> y <code>.reset_index()</code>. Solo año 2024. ✅
# </div>

# %% [markdown]
# ### 🧠 **Momento de reflexión**
#
# ¡Excelente trabajo hasta aquí!
#
# Ahora que ya tienes los promedios anuales por ciudad, es momento de **observarlos** con atención.
#
# Piensa:
#
# - ¿Cuál crees que tiene el mayor tiempo promedio de tráfico?
# - ¿Será una ciudad de **Europa**, de **Latinoamérica** o de **otra región** del mundo?
#
# Para descubrirlo, ejecuta esta línea de código:
#
# `traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)`
#
#
# 🔍 Observa qué ciudad aparece en los primeros lugares.
#
# ¿Te sorprenden los resultados? , ¿Coinciden con lo que imaginabas?

# %%
traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)
# Out:
#             city country  year   jams_delay  traffic_index_live  \
# 221  mexico-city     MEX  2024  2833.057892           34.218190
# 352        tokyo     JPN  2024  2152.574357           36.805059
# 246     new-york     USA  2024  2133.400000           28.210388
# 200       london     GBR  2024  2050.703662           29.230166
# 211       manila     PHL  2024  1741.493381           66.129402
# ..           ...     ...   ...          ...                 ...
# 111      dunedin     NZL  2024     4.651175           15.430809
# 363      uppsala     SWE  2024     4.194486           13.939168
# 123     fujairah     ARE  2024     4.025959           10.907719
# 12        almere     NLD  2024     3.633523            6.290478
# 117      el-paso     USA  2024     0.299024            2.340435
#
#      jams_length_kms  jams_count  mins_delay  travel_time_live_per_10kms_mins  \
# 221       389.239265  594.969392    1.855542                        21.809092
# 352       373.069734  518.809420    0.698152                        22.443778
# 246       398.227892  544.474902    1.396351                        18.505043
# 200       287.632868  471.795554    1.325160                        17.714139
# 211       246.858082  341.881205    2.469894                        27.134629
# ..               ...         ...         ...                              ...
# 111         0.712315    1.591384    0.633294                        16.226009
# 363         0.656368    1.349672    0.501802                        15.746717
# 123         0.731910    1.373006    0.194951                        11.662590
# 12          0.506362    1.064063   -0.017544                         9.467150
# 117         0.031114    0.078118   -0.250676                        10.690269
#
#      travel_time_hist_per_10kms_mins
# 221                        19.953550
# 352                        21.745626
# 246                        17.108691
# 200                        16.388979
# 211                        24.664734
# ..                               ...
# 111                        15.592715
# 363                        15.244916
# 123                        11.467639
# 12                          9.484694
# 117                        10.940945
#
# [387 rows x 10 columns]

# %% [markdown]
# ## La ciudad con el mayor tiempo promedio de tráfico es Ciudad de Mexico (Mexico city, MEX), con un promedio de 2833 min, muy por encima de Tokio (2152 min) o Nueva York (2133 min).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 2)</b>
# Reflexión del Paso 4 excelente: Ciudad de México con el valor exacto (~2833 min), y comparación con Tokyo (2152 min) y Nueva York (2133 min). ✅
# </div>

# %% [markdown]
# La ciudad con el mayor tiempo promedio de tráfico es ...
#
#
# ---
#
# ## 🧩Paso 5: Unir movilidad y economía
#
# Combinar datasets te permite analizar cómo se relacionan los indicadores económicos con los de movilidad.
#
# ### 5.1 Unir tráfico (tabla principal) con indicadores económicos
#
# **🎯Objetivo:**
# Combinar la información de tráfico y economía en un solo DataFrame para analizar cómo las condiciones económicas se relacionan con la movilidad urbana.
#
# **Instrucciones**
# - Selecciona solo las **columnas relevantes** de cada dataset (por ejemplo, variables clave de tráfico y de economía).
# - Usa `.copy()` al crear subconjuntos para evitar modificar el dataset original.
# - Une ambos DataFrames y define como **claves de unión** a `city` y `year`.
# - Mantén solo las ciudades y años presentes en ambos datasets.
# - Guarda el resultado en una nueva variable llamada `merged` y muestra las primeras 5 filas.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor. (Iteración 1)</b>
# Esta celda dice <b>"La ciudad con el mayor tiempo promedio de tráfico es ..."</b> sin completar. La respuesta está en el output de la celda anterior (el sort por <code>jams_delay</code>): es <b>Ciudad de México (mexico-city, MEX)</b>, con un promedio de <b>~2833 minutos</b> — muy por encima de Tokyo (~2152) y Nueva York (~2133).
# </div>

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Aplica una unión de tipo "inner" para mantener las ciudades y años presentes en ambos datasets.

# %%
# Seleccionar columnas clave de tráfico y economía
left_cols = ['city','country','year','jams_delay','traffic_index_live',
             'jams_length_kms','jams_count','mins_delay',
             'travel_time_live_per_10kms_mins','travel_time_hist_per_10kms_mins']

right_cols = ['city','year','city_gdp_capita','unemployment_pct','pm25','population']

# Usar .copy() para crear los dos nuevos datasets reducidos
traffic_2024_small = traffic_city_year_2024[['city','country','year','jams_delay','traffic_index_live','jams_length_kms','jams_count',
                                             'mins_delay', 'travel_time_live_per_10kms_mins','travel_time_hist_per_10kms_mins']].copy()

eco_2024_small = eco_2024[['city','year','city_gdp_capita','unemployment_pct','pm25','population']].copy()

# Unir datasets
merged = pd.merge(traffic_2024_small, eco_2024_small, on=['city', 'year'], how='inner')

# Mostrar las primeras 5 filas
merged.head(5)
merged.sort_values(by = 'jams_delay', ascending = False)
# Out:
#               city country  year   jams_delay  traffic_index_live  \
# 7      mexico-city     MEX  2024  2833.057892           34.218190
# 14       sao-paulo     BRA  2024  1729.189270           26.877932
# 1           bogota     COL  2024  1141.552364           37.614273
# 6             lima     PER  2024  1052.292789           31.031277
# 13        santiago     CHL  2024   629.865318           20.155352
# 3     buenos-aires     ARG  2024   571.089593           17.756012
# 11  rio-de-janeiro     BRA  2024   466.064706           25.162963
# 0   belo-horizonte     BRA  2024   263.047879           19.428946
# 4         curitiba     BRA  2024   183.469274           14.954545
# 9     porto-alegre     BRA  2024   139.382830           17.687254
# 10          recife     BRA  2024   112.755551           21.555944
# 2         brasilia     BRA  2024   101.576326           11.258220
# 12        salvador     BRA  2024    86.400000           20.928728
# 5        fortaleza     BRA  2024    82.813181           15.896749
# 8       montevideo     URY  2024    50.201092           17.014854
#
#     jams_length_kms  jams_count  mins_delay  travel_time_live_per_10kms_mins  \
# 7        389.239265  594.969392    1.855542                        21.809092
# 14       238.419896  431.470460    1.129026                        20.801836
# 1        140.893564  230.566550    1.699628                        24.992185
# 6        110.314770  213.453519    1.506305                        25.674261
# 13        93.489121  153.095300    0.627445                        17.031310
# 3        100.287844  137.359860    0.416566                        17.907916
# 11        85.015120  123.891939    0.361302                        17.137320
# 0         44.038129   68.805422    0.487228                        18.304538
# 4         30.050044   46.898164    0.139965                        17.258700
# 9         20.167849   39.813403    0.194195                        16.166684
# 10        16.885490   33.221154    0.072539                        20.101569
# 2         18.337133   27.280140    0.193442                        13.338658
# 12        13.170442   25.235243    0.115811                        16.831620
# 5         11.205844   24.644991    0.081618                        19.267171
# 8          6.369201   14.160332    0.393442                        18.892342
#
#     travel_time_hist_per_10kms_mins  city_gdp_capita  unemployment_pct   pm25  \
# 7                         19.953550          21111.0               3.2  22,30
# 14                        19.672810          14703.0               8.5  28,00
# 1                         23.292557          11442.0              10.0  17,60
# 6                         24.167956          13472.0               6.5  19,70
# 13                        16.403864           2277.0               7.8  21,30
# 3                         17.491349          18117.0               7.2  14,50
# 11                        16.776018          13349.0               9.2  18,40
# 0                         17.817311          11124.0               9.5  16,80
# 4                         17.118736          12381.0               8.2  13,50
# 9                         15.972490          11801.0               8.7  14,20
# 10                        20.029030           9189.0              11.2  15,80
# 2                         13.145216          16251.0               7.8  12,80
# 12                        16.715810           8899.0              12.4  15,20
# 5                         19.185554           8512.0              11.8  14,60
# 8                         18.498900          26176.0               8.4  11,20
#
#     population
# 7   22100000.0
# 14  22600000.0
# 1   11300000.0
# 6   11200000.0
# 13   7100000.0
# 3   15400000.0
# 11  13700000.0
# 0    6100000.0
# 4    3700000.0
# 9    4300000.0
# 10   4100000.0
# 2    4800000.0
# 12   3900000.0
# 5    4200000.0
# 8    1800000.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 2)</b>
# Merge correcto: inner join, 15 ciudades latinoamericanas del año 2024. ✅
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Visualización y análisis de relaciones
#
# Ahora que tienes un dataset limpio y unificado, es momento de **visualizar patrones**.
# Los gráficos te ayudarán a entender cómo se relacionan las variables económicas con las de movilidad urbana.
#
# ### 6.1 Visualizar relaciones entre economía y tráfico
#
# **🎯Objetivo:**
# Analizar visualmente la distribución y la relación entre indicadores de tráfico y economía en 2024, para identificar posibles patrones o tendencias generales entre ambas variables.
#
# **Instrucciones**
# - Usa las librerías `seaborn` y `matplotlib.pyplot` para generar los gráficos.
# - Visualiza la distribución del **tráfico** (`jams_delay`) mediante:
#     - **Boxplot** → para observar la media, mediana y detectar valores atípicos.
# - Visualiza la distribución de la **economía** (`city_gdp_capita`) mediante:
#     - **Histograma** → para analizar la forma de la distribución y el valor promedio del PIB per cápita.
# - Finalmente, **compara ambas variables**, para observar si existe alguna relación entre ellas, haciendo un solo gráfico de barras donde aparezcan ambos indicadores.
# - Recuerda agregar título y etiquetas a los ejes de tus gráficos.
# - Observa y comenta los patrones, valores extremos o posibles relaciones que identifiques.

# %% [markdown]
# **Tip:** Dentro de los parentesis del boxplot, agrega `showmeans=True` para ver la media en el gráfico.

# %%
# Crear boxplot para observar el comportamiento de los minutos de congestion JamsDelay
# crea tu gráfico

# obtener promedio para mostrarlo en título
mean_value = merged['jams_delay'].mean()
sns.boxplot(data=merged, x='jams_delay', showmeans=True)
plt.title(f'Boxplot de JamsDelay (2024)\nPromedio: {mean_value:.2f}')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b>
# Boxplot con <code>showmeans=True</code> y promedio en el título. ✅ Buen detalle usar <code>data=merged</code> como parámetro.
# </div>

# %%
# Crear histograma para ver la distribución de la economía (city_gdp_capita)
economia = sns.histplot(data=merged, x="city_gdp_capita", kde=True)
plt.title('Distribucion de la economia')
plt.xlabel('PIB per capita')
plt.ylabel('Frecuencia')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor. (Iteración 1)</b>
# El histograma funciona, pero hay dos detalles a mejorar:
# <ul>
# <li>Usa <code>merged['city_gdp_capita'].hist()</code> (método de pandas) en lugar de <code>sns.histplot()</code> (seaborn). El solucionario usa seaborn con <code>kde=True</code> para añadir la curva de densidad.</li>
# <li>El <code>execution_count = 27</code> de esta celda (vs exec=22 del merge) indica que se ejecutó varias veces mientras la ajustabas. Hacer <i>Restart & Run All</i> antes de entregar asegura que los contadores queden en orden secuencial.</li>
# </ul>
# </div>

# %%
# Gráfico de barras para comparar jams_delay y city_gdp_capita por ciudad
merged.plot(kind='bar', x='city' , y=['jams_delay', 'city_gdp_capita'])
plt.title('Comparativa de PIB vs tiempo de retraso')
plt.xlabel('Ciudad')
plt.ylabel('Indicadores')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor. (Iteración 1)</b>
# El gráfico de barras tiene <code>kind='bar'</code> y <code>xticks(rotation=90)</code>. ✅ Sin embargo, las líneas de título y etiquetas tienen una sintaxis incorrecta:
# <pre>
# plt.tiltle = ('...')   # ← typo: "tiltle" en lugar de "title"; además esto es asignación, no llamada
# plt.xlabel = ('...')   # ← mismo problema con xlabel y ylabel
# </pre>
# Para que el título y las etiquetas funcionen, usa la notación de función con paréntesis:
# <pre>
# plt.title('Comparativa de PIB vs tiempo de retraso')
# plt.xlabel('Ciudad')
# plt.ylabel('Indicadores')
# </pre>
# </div>

# %% [markdown]
# **Tip:** Antes del `plt.show()` agrega el código `plt.xticks(rotation=90)` para rotar las etiquetas del eje X en 90 grados.

# %% [markdown]
# ### 🧠 **Reflexiona**
# Excelente trabajo llegando a esta etapa del análisis. Antes de avanzar, revisa tus gráficos, tómate un momento para pensar:
#
# * ¿Las ciudades con mayor PIB per cápita también presentan más congestión?
#
# * ¿O sucede lo contrario, o no existe una relación clara?

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor. (Iteración 1)</b>
# La celda de reflexión sobre los gráficos dice <b>"Escribe tus comentarios:"</b> sin nada escrito. Por favor observa tus tres gráficos y responde:
# <ul>
# <li>¿Hay una relación entre PIB per cápita y congestión, o no hay patrón claro?</li>
# <li>¿Qué ciudad es el outlier más notorio en el boxplot?</li>
# <li>Recuerda usar lenguaje no causal: "se observa", "los datos sugieren", "podría relacionarse con".</li>
# </ul>
# </div>

# %% [markdown]
# ## Se observa que las ciudades con PIB per Capitá mas alto como ciudad de Mexico, Sao Paulo o Lima tienden a tener un promedio de congestion alto tal es el caso de Ciudad de Mexico que  tiene el segundo PIB y el promedio de congestion de trafico mas elevado de latinoamerica. Sin embargo Lima tiene un PIB relativamente bajo (13472) comparado con Montevideo (26176) o Buenos Aires (18117) pero su promedio de congestion es alto. No considero que exista un patron dado que no necesariamente el alto promedio de congestion en las ciudades tiene que ver con un PIB alto de acuerdo a los datos.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor. (Iteración 2)</b>
# Hay contenido propio en las celdas 54 y 55, lo que es una mejora real. ✅
#
# Un matiz de precisión: la celda 54 dice que Ciudad de México, Sao Paulo y Lima son "las ciudades con PIB per cápita más alto". Sin embargo, Lima tiene un PIB per cápita relativamente bajo (~13472) comparado con Montevideo (~26176), Buenos Aires (~18117) o Ciudad de México (~21111). La correcta característica de CDMX, Sao Paulo y Bogotá es que tienen <b>alta congestión</b>, no necesariamente el PIB más alto.
#
# Además, la celda 53 todavía dice "Escribe tus comentarios:" — el placeholder original quedó ahí. Puedes eliminarlo ahora que tienes las celdas 54 y 55 con el contenido real.
# </div>

# %% [markdown]
# ## Se identifica a la ciudad de Montevideo como el outlier en este estudio pues tiene el PIB per Capitá mas alto y un nivel de congestion bajo lo que provoca se salga del patrón del resto de los paises.

# %% [markdown]
# ---
#
# ## 🧩Paso 7: Exportar y documentar resultados
#
# En esta etapa final consolidarás todo tu trabajo: guardarás el dataset limpio y crearás un resumen que documente los resultados del proyecto.
#
# ### 7.1 Guardar dataset final
#
# **🎯Objetivo:**
# Generar un CSV limpio, reproducible y con columnas relevantes para análisis posterior.
#
# **Instrucciones**
#
# - Exporta el DataFrame `merged` con el nombre: `ladb_mobility_economy_2024_clean.csv`
# - Usa `index=False` para no incluir el índice.

# %%
# Exporta el dataset final como CSV
merged.to_csv("ladb_mobility_economy_2024_clean.csv", index=False)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor. (Iteración 2)</b>
# La celda de exportación del CSV tiene <code>execution_count = None</code> — nunca fue ejecutada. El CSV es uno de los tres entregables del proyecto. Por favor ejecuta esta celda para generar el archivo <code>ladb_mobility_economy_2024_clean.csv</code>.
#
# Después de ejecutarla, haz también <b>Restart & Run All</b> para que todos los <code>execution_count</code> queden en orden lineal (actualmente empiezan en 28, no en 1).
# </div>

# %% [markdown]
# Para poder ver o descargar el archivo generado:
# En el menú lateral que esta a la izquierda, ve hasta la parte de abajo, a la sección de **Exportar dataset** para más información.

# %% [markdown]
# ---
#
# ## ✅ Entregables
#
# 1. **Notebook `.ipynb`** con todas las celdas (código + comentarios).
# 2. **CSV final**: `ladb_mobility_economy_2024_clean.csv`.
# 3. **Resumen ejecutivo breve** en Markdown (3–5 párrafos).

# %% [markdown]
# ---
#
# # 🧾 Resumen ejecutivo (plantilla)
#
# > Completa este resumen al finalizar el análisis. Mantén 3–5 párrafos cortos, claros y accionables.
#
# **Contexto & objetivo:**
# - Responde la pregunta central del análisis: ¿qué relación existe entre la movilidad urbana (congestión, tiempos de viaje) y la productividad económica (PIB per cápita)?
# - Explica brevemente las variables clave utilizadas y su relevancia para la toma de decisiones.
#
# **Cobertura de datos:**
# - Especifica los años analizados, número de ciudades y países incluidos.
#
# **Metodología (alto nivel):**
# - Describe los procesos principales: limpieza de datos (formatos, estandarización de columnas).
# - Explica la agregación por ciudad–año y el uso de una unión INNER para integrar tráfico y economía.
# - Menciona las validaciones visuales empleadas (distribuciones, outliers, tendencias generales).
#
# **Hallazgos iniciales:**
# - Resume los patrones más importantes entre índices de tráfico y PIB per cápita.
# - Destaca anomalías u outliers que podrían requerir revisión adicional o un análisis más profundo.
#
# **Recomendaciones**
# Aterriza los hallazgos en acciones: ciudades prioritarias, necesidad de validar fuentes, requerimiento de análisis adicionales, o propuestas de inversión.
#
# - ¿Qué ciudad : Bogotá, Lima o Buenos Aires o alguna otra en particular, muestra la mayor correlación significativa entre altos niveles de congestión vehicular y bajos indicadores de productividad económica, sugiriendo ser una ciudad prioritaria para inversión en infraestructura de transporte?

# %% [markdown]
# # Resumen Ejecutivo.
#
# ## Este reporte presenta un análisis integral de la economía de movilidad urbana en 15 ciudades de 7 paises latinoamericanos durante el año 2024.
#
# # Indicadores de congestion.
# ## El análisis abarca indicadores de congestión de tráfico, impacto socioeconómico, y contaminación ambiental.
# ## El  top 5 de las ciudades mas congestionadas es:
#
# ## 1. Ciudad de México
# ## 2. Sao Paulo
# ## 3. Bogotá
# ## 4. Lima
# ## 5. Buenos Aires
#
# # Indicadores socioeconomicos.
# ## Se encontraron indicadores socioeconomicos donde el promedio del Pib per Capita es de $13,254, el promedio de la tasa de desesmpleo es de 8.69% y se detecto tambien que 9 ciudades en el estudio superan el promedio de contaminacion recomendado por la OMS.
#
# # Hallazgos Clave.
# ## Se observa una correlación positiva fuerte entre el índice de tráfico y los niveles de PM2.5, sugiriendo que la congestión vehicular es un factor determinante en la contaminación del aire urbano.
# ## Se identifican 3 ciudades críticas que requieren intervención urgente de descongestionamiento.
#
# ## - Ciudad de México
# ## - Sao Paulo
# ## -Bogotá
#
# ## El 60% de las ciudades analizadas superan los estándares de calidad de aire recomendado por la OMS.
#
# # Recomendaciones.
# ## Invertir en sistemas de transporte público integrados, ciclovías y espacios peatonales en ciudades de alto índice de congestión como Bogotá y Ciudad de México.
# ## Establecer límites de emisiones, restricciones vehiculares y promover vehículos      eléctricos.
# ## Implementar plataformas de monitoreo en tiempo real para congestión y contaminación.
# ## Establecer metas para reducir índices de congestión en 10-15% anualmente y alinearse con estándares de calidad de aire internacionales.
#
# # Conclusiones.
# ## La economía de movilidad urbana en América Latina enfrenta desafíos significativos. La congestión de tráfico genera impactos económicos importantes y provocan problemas de contaminación ambiental. Se requiere una estrategia integral que combine inversión en infraestructura en sistemas de transporte público, políticas ambientales efectivas y sistemas de monitoreo avanzados para mejorar la calidad de vida urbana y la sostenibilidad de las ciudades latinoamericanas.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor. (Iteración 2)</b>
# El resumen ejecutivo ahora está en Markdown y tiene una estructura muy completa — eso es un avance enorme. ✅
#
# Sin embargo, el error factual que señalé en la iteración 1 sigue presente: el top 5 coloca a <b>Bogotá como #1</b>, cuando en realidad es <b>Ciudad de México (#1, ~2833 min)</b> la más congestionada dentro de la muestra. El ranking correcto en el dataset que construiste es:
#
# <table>
# <tr><th>#</th><th>Ciudad</th><th>jams_delay</th></tr>
# <tr><td>1</td><td><b>Ciudad de México</b></td><td>~2833 min</td></tr>
# <tr><td>2</td><td>Sao Paulo</td><td>~1729 min</td></tr>
# <tr><td>3</td><td>Bogotá</td><td>~1142 min</td></tr>
# <tr><td>4</td><td>Lima</td><td>~1052 min</td></tr>
# <tr><td>5</td><td>Buenos Aires</td><td>~571 min</td></tr>
# </table>
#
# Por favor corrige el ranking en el resumen. Puedes verificarlo con el sort de tu <code>merged</code> por <code>jams_delay</code>.
# </div>
